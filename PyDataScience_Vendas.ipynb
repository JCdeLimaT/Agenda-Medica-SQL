# %% [markdown]
# <a href="https://colab.research.google.com/github/JCdeLimaT/Agenda-Medica-SQL/blob/main/PyDataScience_Vendas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **[PANDAS] CASE: Vendas**
#
# - Soma de vendas por customer/loja/channel
# - Media de vendas por customer/loja/channel
# - Quantidade de venda geral e agrupado por parceiro
# - Soma de venda geral e agrupado por parceiro
# - Quantidade de customer sem email valido e sem telefone valido

# %% [markdown]
# **Importando Planilhas**

# %%
import pandas as pd

# %%
df_customer = pd.read_csv('/content/DimCustomer - DimCustomer.csv')

# %%
df_customer.head()
# Out:
#    customer_key customer_code  customer_name     segment  \
# 0             1    CUST200001  Cliente 00001      Varejo
# 1             2    CUST200002  cliente 00002  Enterprise
# 2             3    CUST200003  Cliente 00003      Varejo
# 3             4    CUST200004  Cliente 00004         PME
# 4             5    CUST200005  Cliente 00005         PME
#
#                   email  geo_key               email_raw customer_name_dirty  \
# 0  cliente1@exemplo.com       10                       -       Cliente 00001
# 1  cliente2@exemplo.com       17                     NaN       cliente 00002
# 2  cliente3@exemplo.com        2  cliente3 @ exemplo.com       Cliente 00003
# 3  cliente4@exemplo.com       25    cliente4@exemplo.com       Cliente 00004
# 4  cliente5@exemplo.com       10                       -       Cliente 00005
#
#       phone_raw
# 0  31-3456-7890
# 1   21998761234
# 2           NaN
# 3       (vazio)
# 4           NaN

# %%
print(df_customer.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_key         5000 non-null   int64
#  1   customer_code        5000 non-null   object
#  2   customer_name        5000 non-null   object
#  3   segment              5000 non-null   object
#  4   email                4500 non-null   object
#  5   geo_key              5000 non-null   int64
#  6   email_raw            4002 non-null   object
#  7   customer_name_dirty  5000 non-null   object
#  8   phone_raw            3576 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 351.7+ KB
# None

# %%
df_sales = pd.read_csv('/content/FactSales - FactSales.csv')

# %%
df_sales.head()
# Out:
#    sale id    date_key  store_key  salesperson_key  customer_key  product_key  \
# 0      1.0  20241101.0       19.0             97.0         578.0        265.0
# 1      2.0  20251004.0       22.0              NaN        3677.0        276.0
# 2      3.0  20250609.0        2.0              NaN        4999.0         21.0
# 3      4.0  20250324.0        8.0             41.0        1650.0        425.0
# 4      5.0  20240521.0       30.0            158.0        2404.0         61.0
#
#    channel  quantity unit_price discount_rate gross_amount net_amount  \
# 0   Humano       1.0    2603,07         0,191      2603,07    2105,88
# 1  digital       4.0    2123,14         0,148      8492,56    7235,66
# 2  digital       6.0     290,62         0,086      1743,72    1593,76
# 3   Humano       6.0     1708,1         0,091      10248,6    9315,98
# 4   Humano       6.0    3457,31         0,224     20743,86   16097,24
#
# ...

# %%
print(df_sales.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150060 entries, 0 to 150059
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   sale id            150050 non-null  float64
#  1   date_key           150050 non-null  float64
#  2   store_key          150050 non-null  float64
#  3   salesperson_key    132018 non-null  float64
#  4   customer_key       150050 non-null  float64
#  5   product_key        150050 non-null  float64
#  6   channel            147478 non-null  object
#  7   quantity           150050 non-null  float64
#  8   unit_price         150050 non-null  object
#  9   discount_rate      150050 non-null  object
#  10  gross_amount       150050 non-null  object
#  11  net_amount         150050 non-null  object
#  12  cost_amount        150050 non-null  object
#  13  margin_amount      150050 non-null  object
#  14  quantity_txt       138248 non-null  float64
# ...

# %%
df_store = pd.read_csv('/content/DimStore - DimStore.csv')

# %%
df_store.head()
# Out:
#    store_key store_code store_name store_type  geo_key
# 0          1    LOJ1001    Loja 01   Parceiro        7
# 1          2    LOJ1002    Loja 02     Físico       20
# 2          3    LOJ1003    Loja 03     Físico       17
# 3          4    LOJ1004    Loja 04   Parceiro        4
# 4          5    LOJ1005    Loja 05     Online        6

# %%
print(df_store.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   store_key   30 non-null     int64
#  1   store_code  30 non-null     object
#  2   store_name  30 non-null     object
#  3   store_type  30 non-null     object
#  4   geo_key     30 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 1.3+ KB
# None

# %% [markdown]
# **Limpando Dados**

# %%
valores_invalidos = ['-', '(vazio)', '', ' ']

df_customer_limpo = df_customer.replace(valores_invalidos, None)
df_sales_limpo = df_sales.replace(valores_invalidos, None)
df_store_limpo = df_store.replace(valores_invalidos, None)

# %%
df_customer_limpo.head()
# Out:
#    customer_key customer_code  customer_name     segment  \
# 0             1    CUST200001  Cliente 00001      Varejo
# 1             2    CUST200002  cliente 00002  Enterprise
# 2             3    CUST200003  Cliente 00003      Varejo
# 3             4    CUST200004  Cliente 00004         PME
# 4             5    CUST200005  Cliente 00005         PME
#
#                   email  geo_key               email_raw customer_name_dirty  \
# 0  cliente1@exemplo.com       10                    None       Cliente 00001
# 1  cliente2@exemplo.com       17                     NaN       cliente 00002
# 2  cliente3@exemplo.com        2  cliente3 @ exemplo.com       Cliente 00003
# 3  cliente4@exemplo.com       25    cliente4@exemplo.com       Cliente 00004
# 4  cliente5@exemplo.com       10                    None       Cliente 00005
#
#       phone_raw
# 0  31-3456-7890
# 1   21998761234
# 2           NaN
# 3          None
# 4           NaN

# %%
df_sales_limpo.head()
# Out:
#    sale id    date_key  store_key  salesperson_key  customer_key  product_key  \
# 0      1.0  20241101.0       19.0             97.0         578.0        265.0
# 1      2.0  20251004.0       22.0              NaN        3677.0        276.0
# 2      3.0  20250609.0        2.0              NaN        4999.0         21.0
# 3      4.0  20250324.0        8.0             41.0        1650.0        425.0
# 4      5.0  20240521.0       30.0            158.0        2404.0         61.0
#
#    channel  quantity unit_price discount_rate gross_amount net_amount  \
# 0   Humano       1.0    2603,07         0,191      2603,07    2105,88
# 1  digital       4.0    2123,14         0,148      8492,56    7235,66
# 2  digital       6.0     290,62         0,086      1743,72    1593,76
# 3   Humano       6.0     1708,1         0,091      10248,6    9315,98
# 4   Humano       6.0    3457,31         0,224     20743,86   16097,24
#
# ...

# %% [markdown]
# *Dúvida*
#
# se tiver um campo vazio mas escrito de outra forma lá para a linha 500, como eu saberia?

# %% [markdown]
# **Mudando nomenclatura das colunas**

# %%
novos_nomes_customer = {
    'customer_key' : 'Id Cliente',
    'customer_code': 'Código Cliente',
    'customer_name': 'Nome Cliente',
    'segment': 'Segmento',
    'email': 'E-mail',
    'geo_key': 'ID Geo',
    'email_raw': 'E-mail Bruto',
    'customer_name_dirty': 'Nome Bruto',
    'phone_raw': 'Telefone'
}

df_customer_limpo.rename(columns=novos_nomes_customer, inplace=True)

df_customer_limpo.head()
# Out:
#    Id Cliente Código Cliente   Nome Cliente    Segmento                E-mail  \
# 0           1     CUST200001  Cliente 00001      Varejo  cliente1@exemplo.com
# 1           2     CUST200002  cliente 00002  Enterprise  cliente2@exemplo.com
# 2           3     CUST200003  Cliente 00003      Varejo  cliente3@exemplo.com
# 3           4     CUST200004  Cliente 00004         PME  cliente4@exemplo.com
# 4           5     CUST200005  Cliente 00005         PME  cliente5@exemplo.com
#
#    ID Geo            E-mail Bruto     Nome Bruto      Telefone
# 0      10                    None  Cliente 00001  31-3456-7890
# 1      17                     NaN  cliente 00002   21998761234
# 2       2  cliente3 @ exemplo.com  Cliente 00003           NaN
# 3      25    cliente4@exemplo.com  Cliente 00004          None
# 4      10                    None  Cliente 00005           NaN

# %%
novos_nomes_sales = {
    'sale id': 'Id Venda',
    'date_key': 'Data',
    'store_key': 'Loja',
    'salesperson_key': 'Vendedor',
    'customer_key': 'Código Cliente',
    'product_key': 'Produto',
    'channel': 'Canal',
    'quantity': 'Quantidade',
    'unit_price': 'Preço Unitário',
    'discount_rate': 'Desconto',
    'gross_amount': 'Valor Bruto',
    'net_amount': 'Valor Líquido',
    'cost_amount': 'Custo Total',
    'margin_amount': 'Margem de Lucro',
    'quantity_txt': 'Quantidade_txt',
    'unit_price_txt': 'Preço Unitário_txt',
    'discount_rate_pct': 'Desconto_txt',
    'net_amount_txt': 'Valor Líquido_txt',
    'coupon_code': 'Cupom'
}

df_sales_limpo.rename(columns=novos_nomes_sales, inplace=True)

df_sales_limpo.head()
# Out:
#    Id Venda        Data  Loja  Vendedor  Id Cliente  Produto    Canal  \
# 0       1.0  20241101.0  19.0      97.0       578.0    265.0   Humano
# 1       2.0  20251004.0  22.0       NaN      3677.0    276.0  digital
# 2       3.0  20250609.0   2.0       NaN      4999.0     21.0  digital
# 3       4.0  20250324.0   8.0      41.0      1650.0    425.0   Humano
# 4       5.0  20240521.0  30.0     158.0      2404.0     61.0   Humano
#
#    Quantidade Preço Unitário Desconto Valor Bruto Valor Líquido Custo Total  \
# 0         1.0        2603,07    0,191     2603,07       2105,88      2070,7
# 1         4.0        2123,14    0,148     8492,56       7235,66      5810,6
# 2         6.0         290,62    0,086     1743,72       1593,76      1413,6
# 3         6.0         1708,1    0,091     10248,6       9315,98     6950,58
# 4         6.0        3457,31    0,224    20743,86      16097,24     13380,3
#
#   Margem de Lucro  Quantidade_txt Preço Unitário_txt Desconto_txt  \
# ...

# %%
novos_nomes_store = {
    'store_key': 'Loja',
    'store_code': 'Código Loja',
    'store_name': 'Nome Loja',
    'store_type': 'Tipo de Loja',
    'geo_key': 'ID Geo'
}

df_store_limpo.rename(columns=novos_nomes_store, inplace=True)

df_store_limpo.head()
# Out:
#    Loja Código Loja Nome Loja Tipo de Loja  ID Geo
# 0     1     LOJ1001   Loja 01     Parceiro       7
# 1     2     LOJ1002   Loja 02       Físico      20
# 2     3     LOJ1003   Loja 03       Físico      17
# 3     4     LOJ1004   Loja 04     Parceiro       4
# 4     5     LOJ1005   Loja 05       Online       6
